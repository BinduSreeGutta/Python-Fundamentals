# %%
Introduction to python fundamentals

# %%
Understanding the variables in python:

# %%
a=2
b=3
c=a+b
print(c)
# Out:
# 5

# %%
Rules for  declaring the variables in python:

# %%
Rule1 : No namespaces while declaring the variable name

# %%
first name = 'Bindu'
print(first name)
# Out:
#   Cell In[20], line 1
#     first name = 'Bindu'
#           ^
# SyntaxError: invalid syntax

# %%
Rule 2 : A variable name should not start with a number **

# %%
1name = 'Bindu'

print(1name)
# Out:
#   Cell In[8], line 1
#     1name = 'Bindu'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "Bindu"
print(name1)
# Out:
# Bindu

# %%
Rule3 : A variable name should not contain any special characters
@ # $ % &* ( )

# %%
test@ = 'sree'

print(test@)
# Out:
#   Cell In[10], line 1
#     test@ = 'sree'
#           ^
# SyntaxError: invalid syntax

# %%
Introduction to datatypes in python:

1. strings -----> str
2. Numbers -----> integers ---(int) and float (decimals --- 0.1,0.2)
3. list
4. tuple
5. dictionary ------> dict

# %%
classification of datatypes: 


    Broadly datatypes are classified into 2 categeories:

     1. mutable ---> which can edit/ alter ---flexible in nature
     2. Immutable ----> which we cannot edit / alter - fixed in nature

# %%
Introduction to String datatype:

Def: A STring is nothing but a sequence of characters written in quotes.

How do you declare the string

1. approch : using single quote,double quote.

# %%
name = 'Navya'

print(name)
# Out:
# Navya

# %%
name2="Siva"
print(name2)
# Out:
# Siva

# %%
Introduction to String methods

# %%
type(name)
# Out:
# str

# %%
type(123)
# Out:
# int

# %%
type(0.2)
# Out:
# float

# %%
fn="sreeee"
print(fn)
# Out:
# sreeee

# %%
# req: how to correct the format

# %%
print(fn.title())
# Out:
# Sreeee

# %%
# req - entire name into capitals

# %%
print(fn.upper())
# Out:
# SREEEE

# %%
#req- all in small case letters

# %%
print(fn.lower())
# Out:
# sreeee
