# %%
# Introduction to list data type:
#  A list is a collection of items declared in a particular order.
#  List is classified as  a mutable datatype
 List is declared with square bracets -----> []

# %%
students=['bindu','navya','sri','nandu']
print(students)
# Out:
# ['bindu', 'navya', 'sri', 'nandu']

# %%
Indexing:  0,1,2,3,4,5....
# Out:
#   Cell In[22], line 1
#     Indexing:  0,1,2,3,4,5....
#                 ^
# SyntaxError: invalid syntax

# %%
# I want to acess the sri name in the output
print(students[1])
print(students[0])
# Out:
# navya
# bindu

# %%
1. Adding new elements to the list
2. How to modify elements in the list
3. how to delete the elemets in the list
# Out:
#   Cell In[24], line 1
#     1. Adding new elements to the list
#        ^
# SyntaxError: invalid syntax

# %%
students.append('money')
print(students)
# Out:
# ['bindu', 'navya', 'sri', 'nandu', 'money']

# %%
students.insert(2,'masooda')
print(students)
# Out:
# ['bindu', 'navya', 'masooda', 'sri', 'nandu', 'money']

# %%
NOTE: difference between append and insert method in a list datatype

# %%
# i want to modify nandu to nandini

# %%
students[4] = 'nandini'
print(students)
# Out:
# ['bindu', 'navya', 'masooda', 'sri', 'nandini', 'honey', 'honey', 'money', 'money', 'money', 'money', 'money']

# %%
# deleting the sri

# %%
del students[3]
print(students)
# Out:
# ['bindu', 'navya', 'masooda', 'nandini', 'honey', 'honey', 'money', 'money', 'money', 'money', 'money']
