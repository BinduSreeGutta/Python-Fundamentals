# %%
Introduction to f strings:

# %%
firstname = "Bindu"
lastname = "sree"

# %%
#req - i want to get the full name...?
#general syntax of f string....?

# %%
message= f" custom meassage {place_holder_1} {place_holder_2}...{place_holder_n}"

# %%
fullname= f"{firstname} {lastname}"

print(fullname)
# Out:
# Bindu sree

# %%
print(fullname.title())
# Out:
# Bindu Sree

# %%
message = f"keep up the good work, {fullname.title()}"

print(message)
# Out:
# keep up the good work, Bindu Sree

# %%
Intro to WHITE SPACES

# %%
print("Fav_prog:PythoncJavac++swiftjavascript")
# Out:
# Fav_prog:PythoncJavac++swiftjavascript

# %%
print("Fav_prog:\nPython\ncJava\nc++\nswift\njavascript")
# Out:
# Fav_prog:
# Python
# cJava
# c++
# swift
# javascript

# %%
print("Fav_prog:\n\tPython\n\tcJava\n\tc++\n\tswift\n\tjavascript")
# Out:
# Fav_prog:
# 	Python
# 	cJava
# 	c++
# 	swift
# 	javascript

# %%
\t ----> tab delimiter

# %%
eleminating white spaces

# %%
name='python   '
print(name)
# Out:
# python

# %%
name1='     python'

print(name1)
# Out:
#      python

# %%
name2='python'
print(name2)
# Out:
# python

# %%
name1.lstrip()    #left stripping
# Out:
# 'python'

# %%
name.rstrip() #right stripping
# Out:
# '     python'
